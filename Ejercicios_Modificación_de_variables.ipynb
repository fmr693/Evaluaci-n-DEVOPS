# %% [markdown]
# <a href="https://colab.research.google.com/github/fmr693/Evaluaci-n-DEVOPS/blob/main/Ejercicios_Modificaci%C3%B3n_de_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Establecemos el directorio de trabajo

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir(r"/content/drive/MyDrive/Colab Notebooks")

import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Cargar los datos de Train.

# %%
df = pd.read_csv(r"train.csv")

(print(df.head(5)))
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# # 2. Para la variable “MSZoning” eliminar el valor “C (all)” y convertirlo en "C".

# %%
print(df["MSZoning"].unique())

df["MSZoning"] = df["MSZoning"].replace("C (all)", "C")
# Out:
# ['RL' 'RM' 'C (all)' 'FV' 'RH']
# ['RL' 'RM' 'C' 'FV' 'RH']

# %% [markdown]
# # 3. Comprobar que se ha realizado correctamente el cambio.

# %%
print(df["MSZoning"].unique())
# Out:
# ['RL' 'RM' 'C' 'FV' 'RH']

# %% [markdown]
# # 4. Crear una nueva variable que se llame Crisis.

# %%
df['crisis'] = df['YrSold'] >= 2008

# %% [markdown]
# # 5. Convertir esa columna en un valor booleano
# Transformar la variable anterior para determinar (Debe tomar los valores Sí o No), basándose en la variable “YrSold”, si la casa se vendió en el periodo sin crisis (antes de 2008) o tras el estallido de la crisis (a partir de 2008).

# %%
df['crisis'] = df['YrSold'] >= 2008

# %% [markdown]
# Otra manera

# %%
df['crisis'] = np.where(df['YrSold'] >= 2008, "Sí", "No")

# %% [markdown]
# # 6. Comprobar que se ha realizado correctamente.

# %%
df['crisis']
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1455    False
# 1456     True
# 1457     True
# 1458     True
# 1459     True
# Name: crisis, Length: 1460, dtype: bool

# %% [markdown]
# # 7. Crear un nuevo grupo de datos con las 10 casas más caras, en función de la variable “SalePrice”.

# %%
casasmascaras = df.sort_values('SalePrice', ascending=False).head(10)

print(casasmascaras)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 803    804          60       RL        107.0    13891   Pave   NaN      Reg
# 1046  1047          60       RL         85.0    16056   Pave   NaN      IR1
# 440    441          20       RL        105.0    15431   Pave   NaN      Reg
# 769    770          60       RL         47.0    53504   Pave   NaN      IR2
# 178    179          20       RL         63.0    17423   Pave   NaN      IR1
# 798    799          60       RL        104.0    13518   Pave   NaN      Reg
#
#      LandContour Utilities  ...  Fence MiscFeature MiscVal MoSold YrSold  \
# 691          Lvl    AllPub  ...    NaN         NaN       0      1   2007
# 1182         Lvl    AllPub  ...  MnPrv         NaN       0      7   2007
# 1169         Lvl    AllPub  ...    NaN         NaN       0      7   2006
# 898          Lvl    AllPub  ...    NaN         NaN       0      3   2010
# 803          Lvl    AllPub  ...    NaN         NaN       0      1   2009
# 1046         Lvl    AllPub  ...    NaN         NaN       0      7   2006
# 440          Lvl    AllPub  ...    NaN         NaN       0      4   2009
# 769          HLS    AllPub  ...    NaN         NaN       0      6   2010
# 178          Lvl    AllPub  ...    NaN         NaN       0      7   2009
# 798          Lvl    AllPub  ...    NaN         NaN       0      7   2009
#
#      SaleType SaleCondition  SalePrice  crisis  HighestPrice
# 691        WD        Normal     755000   False           1.0
# 1182       WD       Abnorml     745000   False           2.0
# 1169       WD        Normal     625000   False           3.0
# 898       New       Partial     611657    True           4.0
# 803       New       Partial     582933    True           5.0
# 1046      New       Partial     556581   False           6.0
# 440        WD        Normal     555000    True           7.0
# 769        WD        Normal     538000    True           8.0
# 178       New       Partial     501837    True           9.0
# 798       New       Partial     485000    True          10.0
#
# [10 rows x 83 columns]

# %% [markdown]
# # 8. Determinar la calle en la que se encuentra la casa más cara.
# Consulta Cruzada

# %%
fila_mas_cara = df.loc[df['SalePrice'].idxmax()]

fila_mas_cara['street']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'street'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1120328527.py in <cell line: 0>()
#       1 fila_mas_cara = df.loc[df['SalePrice'].idxmax()]
#       2
# ----> 3 fila_mas_cara['street']
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1235
#    1236         # Similar to Index.get_value, but we do not fall back to positional
# -> 1237         loc = self.index.get_loc(label)
#    1238
#    1239         if is_integer(loc):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'street'

# %% [markdown]
# # 9. Crear una variable llamada “Reforma” y que muestre los años que pasaron entre la última  reforma y la venta (YrSold-YearRemodAdd).

# %%
df['Reforma'] = df['YrSold'] - df['YearRemodAdd']

df['Reforma']
# Out:
# 0        5
# 1       31
# 2        6
# 3       36
# 4        8
#         ..
# 1455     7
# 1456    22
# 1457     4
# 1458    14
# 1459    43
# Name: Reforma, Length: 1460, dtype: int64

# %% [markdown]
# # 11. Guardar los datos.

# %%
df.to_csv('train_modificado.csv', index=False)
